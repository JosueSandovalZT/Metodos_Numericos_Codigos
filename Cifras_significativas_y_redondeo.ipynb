# %% [markdown]
# <a href="https://colab.research.google.com/github/JosueSandovalZT/Metodos_Numericos_Codigos/blob/main/Cifras_significativas_y_redondeo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 4: Cifras significativas y redondeo

# %%
import numpy as np # Importamos la librería NumPy para operaciones numéricas

# %%
X = 3.1415926535 # Define una variable X con el valor aproximado de pi

print(round(X, 2)) # Muestra el valor de X redondeado a 2 decimales
print(round(X, 4)) # Muestra el valor de X redondeado a 4 decimales
print(round(X, 6)) # Muestra el valor de X redondeado a 6 decimales
# Out:
# 3.14
# 3.1416
# 3.141593
